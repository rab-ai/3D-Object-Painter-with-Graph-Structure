# %% [markdown]
# <a href="https://colab.research.google.com/github/rab-ai/3D-Object-Painter-with-Graph-Structure/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install peft
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="MHhDBkPAB4O95NXvzK8Q")
project = rf.workspace("university-of-strathclyde-m436x").project("crime-c2vas")
version = project.version(4)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from datasets import load_dataset

dataset = load_dataset('/content/crime-4/train/', split="train")
# Out:
# Resolving data files:   0%|          | 0/6237 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>}

# %%
dataset["images"][0]
# Out:
# {'id': 0,
#  'license': 1,
#  'file_name': '1671_jpg.rf.d8d5a0a7399fa74eb71865314242544d.jpg',
#  'height': 640,
#  'width': 640,
#  'date_captured': '2024-02-05T06:31:34+00:00'}

# %%
from torch.utils.data import Dataset, DataLoader

class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        encoding = self.processor(images=item["image"], padding="max_length", return_tensors="pt")
        # remove batch dimension
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["text"] = item["text"]
        return encoding

def collate_fn(batch):
    # pad the input_ids and attention_mask
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer(
                [example["text"] for example in batch], padding=True, return_tensors="pt"
            )
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
    return processed_batch

# %%
from transformers import AutoProcessor, Blip2ForConditionalGeneration

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("ybelkada/blip2-opt-2.7b-fp16-sharded", device_map="auto", load_in_8bit=True)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
from peft import LoraConfig, get_peft_model

# Let's define the LoraConfig
config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules=["q_proj", "k_proj"]
)

model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-328-2e02b0784e1d> in <cell line: 12>()
#      10 )
#      11
# ---> 12 model = get_peft_model(model, config)
#      13 model.print_trainable_parameters()
#      14
#
# /usr/local/lib/python3.10/dist-packages/peft/mapping.py in get_peft_model(model, peft_config, adapter_name, mixed)
#     137         model ([`transformers.PreTrainedModel`]):
#     138             Model to be wrapped.
# --> 139         peft_config ([`PeftConfig`]):
#     140             Configuration object containing the parameters of the Peft model.
#     141         adapter_name (`str`, `optional`, defaults to `"default"`):
#
# AttributeError: 'torch.device' object has no attribute '__dict__'

# %%
train_dataset = ImageCaptioningDataset(dataset, processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)

# %%
train_dataset[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-251-a0be1c17c5b0> in <cell line: 1>()
# ----> 1 train_dataset[0]
#
# <ipython-input-249-87c830a6792d> in __getitem__(self, idx)
#      10
#      11     def __getitem__(self, idx):
# ---> 12         item = self.dataset[idx]
#      13         encoding = self.processor(images=item["images"], padding="max_length", return_tensors="pt")
#      14         # remove batch dimension
#
# KeyError: 0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-327-a2cd5af04264> in <cell line: 3>()
#       1 import torch
#       2
# ----> 3 optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
#       4
#       5 device = "cuda" if torch.cuda.is_available() else "cpu"
#
# AttributeError: 'torch.device' object has no attribute 'parameters'

# %%
help(enumerate(train_dataloader))
# Out:
# Help on enumerate object:
#
# class enumerate(object)
#  |  enumerate(iterable, start=0)
#  |
#  |  Return an enumerate object.
#  |
#  |    iterable
#  |      an object supporting iteration
#  |
#  |  The enumerate object yields pairs containing a count (from start, which
#  |  defaults to zero) and a value yielded by the iterable argument.
#  |
#  |  enumerate is useful for obtaining an indexed list:
#  |      (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
# ...

# %%
torch.cuda.set_device(0)
# On device 0
with torch.cuda.device(1):
    print("Inside device is 1")
    # On device 1
print("Outside is still 0")
# On device 0
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-332-2e2a583436b6> in <cell line: 3>()
#       1 torch.cuda.set_device(0)
#       2 # On device 0
# ----> 3 with torch.cuda.device(1):
#       4     print("Inside device is 1")
#       5     # On device 1
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py in __enter__(self)
#     363
#     364     def __enter__(self):
# --> 365         self.prev_idx = torch.cuda._exchange_device(self.idx)
#     366
#     367     def __exit__(self, type: Any, value: Any, traceback: Any):
#
# RuntimeError: CUDA error: invalid device ordinal
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

model.train()
n = 0
for epoch in range(2):
    print("Epoch:", epoch)
    for idx, batch in enumerate(train_dataloader):
        input_ids = batch["input_ids"].to(device)
        pixel_values = batch["pixel_values"].to(device, torch.float32)

        outputs = model(input_ids=input_ids, pixel_values=pixel_values, labels=input_ids)

        loss = outputs.loss

        print("Loss:", loss.item())

        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        if n >= 10:
            break
        n += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-333-d21ffcb64354> in <cell line: 2>()
#       1 device = "cuda" if torch.cuda.is_available() else "cpu"
# ----> 2 model.to(device)
#       3
#       4 model.train()
#       5 n = 0
#
# AttributeError: 'torch.device' object has no attribute 'to'

# %%
image = "/content/crime-4/train/"+dataset["images"][8]['file_name']
type(image)
image
image = Image.open(image).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# prepare image for the model
inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
pixel_values = inputs.pixel_values

generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(generated_caption)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# a man with a hat and a gun is aiming at a gun

# %%
import json
from PIL import Image

# %%
with open('/content/crime-4/train/_annotations.coco.json', 'r') as f:
    dataset = json.load(f)
dataset['images'][4000]
# Out:
# {'id': 4000,
#  'license': 1,
#  'file_name': '1007_jpg.rf.a30c9d0fea87f593b39754562ded292f.jpg',
#  'height': 640,
#  'width': 640,
#  'date_captured': '2024-02-05T06:31:34+00:00'}

# %%
# !pip install plt
# Out:
# ERROR: Could not find a version that satisfies the requirement plt (from versions: none)
# ERROR: No matching distribution found for plt

# %%
# prepare image for the model
inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
pixel_values = inputs.pixel_values

generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(generated_caption)
# Out:
# a man is practicing a martial move with another man

# %%
image = "/content/crime-4/train/"+dataset['images'][0]["file_name"]
image = Image.open(image).convert("RGB")
image
type(image)
# Out:
# str

# %%
import torch
from matplotlib import pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"

fig = plt.figure(figsize=(18, 14))
#image = dataset['images'][0]["file_name"]
image=  "/content/crime-4/train/"+dataset['images'][0]["file_name"]
image = Image.open(image).convert("RGB")
# prepare image for the model
#image = example["image"]
prompt = "Question: What is happening in this picture? Answer:"
inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
#pixel_values = inputs.pixel_values

generated_ids = model.generate(**inputs, max_new_tokens=10)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()

#plt.imshow(image)
#plt.axis("off")
print(f"Generated caption: {generated_caption}")
# Out:
# Both `max_new_tokens` (=10) and `max_length`(=51) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated caption: a silver pistol with a black grip on a white

# %%
example = dataset["images"][0]

example
# Out:
# {'id': 0,
#  'license': 1,
#  'file_name': '1671_jpg.rf.d8d5a0a7399fa74eb71865314242544d.jpg',
#  'height': 640,
#  'width': 640,
#  'date_captured': '2024-02-05T06:31:34+00:00'}

# %%
n=0
with open('caption.txt', 'w') as output_file:
    for image_info in data['images']:
        image_path = "/content/crime-4/train/"+dataset['images'][n]['file_name']  # update with the actual path to images
        image = Image.open(image_path).convert("RGB")
        #print(f"/content/crime-4/train/{image_info['file_name']}")
        #a = dataset[n]
        print(a)
        # Prepare image for the model
        prompt = "Question: What is happening in this picture? Answer:"
        inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
        pixel_values = inputs.pixel_values

        # Generate caption
        generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
        generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

        # Write the generated caption to the file
        output_file.write(generated_caption)
        print(n)
        n += 1
        if(n>10):
          break
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 0
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 1
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 2
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 3
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 4
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 5
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 6
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7B508B8313C0>, 'label': None}
# 7
# ...

# %%
image = "/content/crime-4/train/"+dataset["images"][11]['file_name']
type(image)
image
image = Image.open(image).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# Update the original dataset with the generated captions
with open('caption.txt', 'r') as caption_file:
    captions = caption_file.readlines()

# Trim the newline characters from the captions
captions = [caption.strip() for caption in captions]
i=0
for image_info in data['images']:

    dataset['images'][i]['text'] = captions[i]
    i+=1
    if(i>=len(captions)):
      break

# %%
captions[99]
# Out:
# 'two men sitting at a table with a knife and a knife block'

# %%
image = dataset["images"][10]
image
# Out:
# {'id': 10,
#  'license': 1,
#  'file_name': '1494_jpg.rf.d8057bfe49227feb1512686e913fa5de.jpg',
#  'height': 640,
#  'width': 640,
#  'date_captured': '2024-02-05T06:31:34+00:00',
#  'text': 'a gun with a silver finish and black grip'}

# %%
image = "/content/crime-4/train/"+dataset["images"][10]['file_name']
image = Image.open(image).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
from torch.utils.data import Dataset, DataLoader

class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        encoding = self.processor(images=item["image"], padding="max_length", return_tensors="pt")
        # remove batch dimension
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["text"] = item["text"]
        return encoding

def collate_fn(batch):
    # pad the input_ids and attention_mask
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer(
                [example["text"] for example in batch], padding=True, return_tensors="pt"
            )
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
    return processed_batch

# %%
import torch

# Assuming you have a processor instance defined
# processor = ...

train_dataset = ImageCaptioningDataset(dataset["images"], processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)

# Model and optimizer setup (assuming you have a predefined model)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

model.train()
n = 0
for epoch in range(2):
    print("Epoch:", epoch)
    for idx, batch in enumerate(train_dataloader):
        input_ids = batch["input_ids"].to(device)
        pixel_values = batch["pixel_values"].to(device, torch.float32)
        attention_mask = batch["attention_mask"].to(device)

        outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, labels=input_ids)

        loss = outputs.loss

        print("Loss:", loss.item())

        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        if n >= 10:
            break
        n += 1
# Out:
# WARNING:accelerate.big_modeling:You shouldn't move a model that is dispatched using accelerate hooks.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-306-db32e2f88aad> in <cell line: 12>()
#      10 optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
#      11 device = "cuda" if torch.cuda.is_available() else "cpu"
# ---> 12 model.to(device)
#      13
#      14 model.train()
#
# /usr/local/lib/python3.10/dist-packages/accelerate/big_modeling.py in wrapper(*args, **kwargs)
#     454                     if param.device == torch.device("meta"):
#     455                         raise RuntimeError("You can't move a model that has some modules offloaded to cpu or disk.")
# --> 456                 return fn(*args, **kwargs)
#     457
#     458             return wrapper
#
# ...

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# !pip install -q einops
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoProcessor, Blip2ForConditionalGeneration

# Load the dataset from the JSON file
with open('dataset.json', 'r') as f:
    dataset = json.load(f)

# Define the processor and model
processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("ybelkada/blip2-opt-2.7b-fp16-sharded", device_map="auto", load_in_8bit=True)

class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        image_path = item["file_name"]
        text = item["text"]

        # Load and process image
        encoding = self.processor(images=image_path, return_tensors="pt", padding="max_length")
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["text"] = text
        return encoding

def collate_fn(batch):
    # Pad the input_ids and attention_mask
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer(
                [example["text"] for example in batch], padding=True, return_tensors="pt"
            )
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
    return processed_batch

# Initialize dataset and dataloader
train_dataset = ImageCaptioningDataset(dataset["images"], processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)

# Model and optimizer setup
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

# Training Loop
model.train()
n = 0
for epoch in range(2):
    print("Epoch:", epoch)
    for idx, batch in enumerate(train_dataloader):
        input_ids = batch["input_ids"].to(device)
        pixel_values = batch["pixel_values"].to(device, torch.float32)
        attention_mask = batch["attention_mask"].to(device)

        outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, labels=input_ids)

        loss = outputs.loss

        print("Loss:", loss.item())

        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        if n >= 10:
            break
        n += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-315-901832866cea> in <cell line: 44>()
#      42
#      43 # Model and optimizer setup
# ---> 44 optimizer = torch.optim.Adam(model.device.parameters(), lr=5e-4)
#      45
#      46 device = "cuda" if torch.cuda.is_available() else "cpu"
#
# AttributeError: 'torch.device' object has no attribute 'device'
